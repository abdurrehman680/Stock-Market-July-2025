# %% [markdown]
# # Risk Assesement

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import kpss
from statsmodels.tsa.seasonal import STL
from scipy.stats import ks_2samp

import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import datetime as time

# %%
stock_data_june = pd.read_csv("stock_market_june2025.csv")
stock_data_53 = pd.read_csv("stock_data_july_2025.csv")

# %%
pd.reset_option('display.max_rows')
stock_data_june['Ticker'].value_counts().gt(2).sum()
# Out:
# np.int64(0)

# %%
# Checking tickers that appear more than once
stock_data_53['Ticker'].value_counts().gt(1).sum()
# Checking tickers that appear more than twice
stock_data_53['Ticker'].value_counts().gt(2).sum()

# Filtering
valid_tickers = stock_data_53['Ticker'].value_counts()
valid_tickers = valid_tickers[valid_tickers > 2].index
sorted_stock_data = stock_data_53[stock_data_53['Ticker'].isin(valid_tickers)]

# %%
len(sorted_stock_data)
# Out:
# 4346

# %%
# Sorting the df
sorted_stock_data["Date"] = pd.to_datetime(sorted_stock_data["Date"], dayfirst=True, format="mixed")
sorted_stock_data = sorted_stock_data.sort_values(['Ticker', 'Date'])

# %% [markdown]
# ### Percentage Change

# %%
# Calculating percentage change
sorted_stock_data['Return'] = sorted_stock_data.groupby('Ticker')['Close Price'].pct_change()
# sorted_stock_data

# %% [markdown]
# ### Volatility

# %%
# Volatility
volatility = sorted_stock_data.groupby('Ticker')['Return'].std()
volatility.dropna(inplace=True)
volatility.to_csv('volatility-by-ticker.csv')
volatility
# Out:
# Ticker
# AAPL    0.086784
# ABBV    0.042445
# ABT     0.037279
# ADBE    0.041914
# ADP     0.035419
#           ...
# VRTX    0.042495
# VZ      0.052715
# WMT     0.044150
# XOM     0.055278
# ZTS     0.030220
# Name: Return, Length: 82, dtype: float64

# %% [markdown]
# ### Value At Risk

# %%
# Value at Risk
Var_95_by_ticker = sorted_stock_data.groupby('Ticker')['Return'].apply(
    lambda x: np.percentile(x.dropna(), 5)
)
Var_95_by_ticker.to_csv('VaR-by-ticker.csv')
Var_95_by_ticker
# Out:
# Ticker
# AAPL   -0.133907
# ABBV   -0.057638
# ABT    -0.074918
# ADBE   -0.077749
# ADP    -0.052902
#           ...
# VRTX   -0.067699
# VZ     -0.072813
# WMT    -0.074621
# XOM    -0.080478
# ZTS    -0.041769
# Name: Return, Length: 82, dtype: float64

# %% [markdown]
# ### Conditional VaR

# %%
# Conditional VaR
CVaR_95_by_Ticker = sorted_stock_data.groupby('Ticker')['Return'].apply(
    lambda x: x[x <= np.percentile(x.dropna(), 5)].mean()
)
CVaR_95_by_Ticker.to_csv('CVaR-by-Ticker.csv')

# %% [markdown]
# ### Drawdown

# %%
# Cumulative Return Calculation
sorted_stock_data['CumulativeReturn'] = (1 + sorted_stock_data['Return']).groupby(sorted_stock_data['Ticker']).cumprod()
sorted_stock_data
# Out:
#            Date Ticker  Open Price  Close Price  High Price  Low Price  \
# 0    2025-06-01   AAPL      185.96       187.79      188.85     183.74
# 82   2025-06-02   AAPL      211.57       213.07      214.91     210.10
# 164  2025-06-03   AAPL      197.75       195.61      200.13     193.48
# 246  2025-06-04   AAPL      215.31       215.44      217.79     214.77
# 328  2025-06-05   AAPL      218.80       226.08      228.69     216.68
# ...         ...    ...         ...          ...         ...        ...
# 4017 2025-07-19    ZTS      148.47       150.37      151.55     146.39
# 4099 2025-07-20    ZTS      151.07       153.32      155.38     150.46
# 4181 2025-07-21    ZTS      151.99       155.44      155.89     151.43
# 4263 2025-07-22    ZTS      152.62       153.82      154.48     152.17
# 4345 2025-07-23    ZTS      146.81       148.32      150.25     145.16
#
#       Volume Traded    Market Cap  PE Ratio  Dividend Yield   EPS  \
# 0          42257183  2.931356e+12     28.37            0.49  6.62
# 82         49806398  3.325971e+12     25.98            0.51  8.20
# 164        29588431  3.053424e+12     30.35            0.52  6.45
# 246        38591730  3.362966e+12     25.26            0.47  8.53
# 328        73159323  3.529054e+12     30.97            0.46  7.30
# ...             ...           ...       ...             ...   ...
# 4017       12037381  6.816773e+10     24.13            0.67  6.23
# 4099       14732929  6.950507e+10     27.69            0.69  5.54
# 4181       13736603  7.046613e+10     24.03            0.74  6.47
# 4263        5155784  6.973173e+10     25.35            0.73  6.07
# 4345        5102989  6.723840e+10     29.39            0.74  5.05
#
#       52 Week High  52 Week Low      Sector    Return  CumulativeReturn
# 0           248.20       155.68  Technology       NaN               NaN
# 82          258.68       176.02  Technology  0.134618          1.134618
# 164         233.17       159.61  Technology -0.081945          1.041642
# 246         288.47       156.36  Technology  0.101375          1.147239
# 328         284.50       157.83  Technology  0.049387          1.203898
# ...            ...          ...         ...       ...               ...
# 4017        187.11        98.49  Healthcare -0.004568          0.975352
# 4099        203.09       123.42  Healthcare  0.019618          0.994487
# 4181        176.39       115.89  Healthcare  0.013827          1.008238
# 4263        184.00       124.96  Healthcare -0.010422          0.997730
# 4345        184.27       110.21  Healthcare -0.035756          0.962055
#
# [4346 rows x 16 columns]

# %%
# Running Maximum Calcualtion
sorted_stock_data['RunningMax'] = sorted_stock_data.groupby('Ticker')['CumulativeReturn'].cummax()

# %%
# Drawdown Calculation
sorted_stock_data['Drawdown'] = sorted_stock_data['CumulativeReturn'] / sorted_stock_data['RunningMax'] - 1
max_drawdown = sorted_stock_data.groupby('Ticker')['Drawdown'].min()
sorted_stock_data.to_csv('data-with-drawdown.csv')

# %%
stock_data = stock_data_june

# %%
stock_data_july.columns
# Out:
# Index(['Date', 'Ticker', 'Open Price', 'Close Price', 'High Price',
#        'Low Price', 'Volume Traded', 'Market Cap', 'PE Ratio',
#        'Dividend Yield', 'EPS', '52 Week High', '52 Week Low', 'Sector'],
#       dtype='object')

# %%
stock_data_53['Date']= pd.to_datetime(stock_data_july['Date'])
stock_data_june['Date']= pd.to_datetime(stock_data_june['Date'], format='%d-%m-%Y')

filtered = stock_data_53[stock_data_53['Date'] <= '2025-06-30']
stock_data_june.reset_index(drop=True).equals(filtered.reset_index(drobp=True))
# Out:
# False

# %%
stock_data_june['Ticker'].value_counts()
# Out:
# Ticker
# OUF    2
# XVD    2
# CLL    2
# GFF    2
# TXP    2
#       ..
# JKX    1
# OUV    1
# KOM    1
# LJX    1
# UAA    1
# Name: count, Length: 1691, dtype: int64

# %%
filtered['Ticker'].value_counts()
# Out:
# Ticker
# AAPL     30
# REGN     30
# PYPL     30
# PM       30
# PLD      30
#          ..
# GOOGL    30
# GILD     30
# GE       30
# ELV      30
# ZTS      30
# Name: count, Length: 82, dtype: int64

# %% [markdown]
# # Time Series Analysis

# %% [markdown]
# #### Data is being grouped by the columns Date and closing price. Means of all closing prices each day are taken

# %%
# stock_data["Date"] = pd.to_datetime(stock_data["Date"], dayfirst=True)
stock_data = stock_data.sort_values(by="Date")

# %%
daily_avg = stock_data.groupby("Date")["Close Price"].mean().reset_index()

# %%
plt.figure(figsize=(12,6))
plt.plot(daily_avg["Date"], daily_avg["Close Price"], label= "Close Price", color = "blue")
plt.title("Stock Close Price Over Time")
plt.xlabel("Date")
plt.xticks(rotation=45)
plt.ylabel("Price")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Classical Decomposition using seasonal_decompose function of statsmodels library

# %%
decomposition = seasonal_decompose(daily_avg["Close Price"], model="additive", period=7)
trend = decomposition.trend
seasonsal = decomposition.seasonal
residual = decomposition.resid

# %%
plt.figure(figsize=(10, 4))
plt.subplot(411)
plt.plot(daily_avg["Date"], daily_avg["Close Price"], label = "Original", color= "pink")
plt.legend(loc="upper left")
plt.subplot(412)
plt.plot(daily_avg["Date"], trend, label = "Trend", color= "pink")
plt.legend(loc="upper left")
plt.subplot(413)
plt.plot(daily_avg["Date"], seasonsal, label = "Seasonality", color= "green")
plt.legend(loc="upper left")
plt.subplot(414)
plt.plot(daily_avg["Date"], residual, label = "Residual", color= "orange")
plt.legend(loc="upper left")
plt.tight_layout()

# %% [markdown]
# ### STL Decomposition

# %%
stl_decomp = STL(daily_avg["Close Price"], period=7).fit()

# %%
plt.figure(figsize=(10, 4))
plt.subplot(411)
plt.plot(daily_avg["Date"] ,stl_decomp.observed, label="Original", color="orange")
plt.legend(loc="upper left")
plt.subplot(412)
plt.plot(daily_avg["Date"] ,stl_decomp.trend, label="Trend", color="grey")
plt.legend(loc="upper left")
plt.subplot(413)
plt.plot(daily_avg["Date"], stl_decomp.seasonal, label="Seasonal", color="grey")
plt.legend(loc="upper left")
plt.subplot(414)
plt.plot(daily_avg["Date"], stl_decomp.resid, label="Residual", color="black")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Checking Stationarity
# #### Performing Adf Test

# %%
adf_test = adfuller(daily_avg["Close Price"])
print(f"ADF Statistics: {round(adf_test[0], 3)}")
print(f"p-value: {round(adf_test[1], 3)}")
print("Critical Values")
for key, value in adf_test[4].items():
    print(f"{key}: {round(value, 3)}")
# Out:
# ADF Statistics: -1.634
# p-value: 0.466
# Critical Values
# 1%: -3.523
# 5%: -2.902
# 10%: -2.588

# %% [markdown]
# #### Performing KPSS Test

# %%
kpss_test = kpss(daily_avg["Close Price"], regression="ct")
print(f"KPSS Statistics: {round(kpss_test[0], 2)}")
print(f"p-value: {kpss_test[1]}")
for key, value in kpss_test[3].items():
    print(f"{key}: {value}")
# Out:
# KPSS Statistics: 0.26
# p-value: 0.01
# 10%: 0.119
# 5%: 0.146
# 2.5%: 0.176
# 1%: 0.216

# %% [markdown]
# #### Performing KS Test to check strict stationarity

# %%
def ks_test_stationarity(series):
    split = len(series) //2
    first_half = series[:split]
    second_half = series[split:]
    stat, p_value  = ks_2samp(first_half, second_half)
    return stat, p_value

ks_stat, ks_p_value = ks_test_stationarity(daily_avg["Close Price"])
print(ks_stat, ks_p_value)
# Out:
# 0.5405405405405406 2.6284010564309513e-05

# %% [markdown]
# #### Conclusion:
# #### There is a conflict between the adf and kpss tests because the provided data is of 21 days which is not suitable for either of the tests to provide accurate results. Thereby, stationarity of data remains ambiguous
